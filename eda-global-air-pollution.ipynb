# %% [markdown]
# <a href="https://www.kaggle.com/code/sazidthe1/eda-global-air-pollution?scriptVersionId=166781491" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:175%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">EDA | Global Air Pollution</p>
#
#
# <p style="text-align:center; ">
# <img src="https://img.freepik.com/free-photo/wide-angle-shot-white-smoke-coming-out-nuclear-plants_181624-14959.jpg", style='width: 1000px; height: 600px;'>
# </p>
#
#
# Global air pollution poses a significant environmental and public health challenge, resulting from various human activities and natural processes. Emissions from industries, transportation, agriculture, and energy production release pollutants such as particulate matter, nitrogen oxides, sulfur dioxide, and volatile organic compounds into the atmosphere.
#
# These pollutants contribute to smog formation, acid rain, climate change, and adverse health effects, impacting respiratory and cardiovascular systems and exacerbating existing health conditions. Mitigating global air pollution requires concerted efforts through policy interventions, technological innovations, and public awareness campaigns to safeguard human health and preserve the planet's ecosystems.

# %% [markdown]
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:100">Table of Contents</p>
#
#
# |No  | Contents |
# |:---| :---     |
# |1   | [<font color="#0f4c5c"> Importing Libraries</font>](#1)                   |
# |2   | [<font color="#0f4c5c"> Dataset Description</font>](#2)                   |
# |3   | [<font color="#0f4c5c"> Basic Exploration</font>](#3)                     |
# |4   | [<font color="#0f4c5c"> Dataset Summary</font>](#4)                       |
# |5   | [<font color="#0f4c5c"> EDA: Global Air Pollution</font>](#5)           |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
# pd.set_option('max_columns', 200)
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Reading the Dataset**

# %%
df = pd.read_csv('/kaggle/input/global-air-pollution-data/global_air_pollution_data.csv')

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Dataset Description</p>
#
# <div style = "color: Black; display: fill;
#               border-radius: 5px;
#               background-color: #F2E6CE;
#               font-size: 100%;
#               font-family: Verdana">
#     <p style = "padding: 7px; color: Black;">
#         <ul>
#     📌 <b>country_name</b> - Name of the Country<br>
#     📌 <b>city_name</b> - Name of the City<br>
#     📌 <b>aqi_value</b> - Overall AQI value of the city<br>
#     📌 <b>aqi_category</b> - Overall AQI category of the city<br>
#     📌 <b>co_aqi_value</b> - AQI value of Carbon Monoxide of the city<br>
#     📌 <b>co_aqi_category</b> - AQI category of Carbon Monoxide of the city<br>
#     📌 <b>ozone_aqi_value</b> - AQI value of Ozone of the city<br>
#     📌 <b>ozone_aqi_category</b> - AQI category of Ozone of the city<br>
#     📌 <b>no2_aqi_value</b> - AQI value of Nitrogen Dioxide of the city<br>
#     📌 <b>no2_aqi_category</b> - AQI category of Nitrogen Dioxide of the city<br>
#     📌 <b>pm2.5_aqi_value</b> - AQI value of Particulate Matter with a diameter of 2.5 micrometers or less of the city<br>
#     📌 <b>pm2.5_aqi_category</b> - AQI category of Particulate Matter with a diameter of 2.5 micrometers or less of the city<br>
# </ul>

# %% [markdown]
# **Quick Glimpse of the Dataset**

# %%
df.head(n=5).style.set_properties(**{"background-color": "#957DAD","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Basic Exploration</p>

# %% [markdown]
# **Understanding the DataFrame**

# %%
print(f"Shape Of The Dataset: {df.shape}")
# Out:
# Shape Of The Dataset: (23463, 12)

# %% [markdown]
# **Checking Data Types**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23463 entries, 0 to 23462
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country_name        23036 non-null  object
#  1   city_name           23462 non-null  object
#  2   aqi_value           23463 non-null  int64
#  3   aqi_category        23463 non-null  object
#  4   co_aqi_value	       23463 non-null  int64
#  5   co_aqi_category     23463 non-null  object
#  6   ozone_aqi_value     23463 non-null  int64
#  7   ozone_aqi_category  23463 non-null  object
#  8   no2_aqi_value       23463 non-null  int64
#  9   no2_aqi_category    23463 non-null  object
#  10  pm2.5_aqi_value     23463 non-null  int64
#  11  pm2.5_aqi_category  23463 non-null  object
# dtypes: int64(5), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# **Checking the Missing Value**

# %%
df.isnull().sum().to_frame().style.set_properties(**{"background-color": "#957DAD","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_7309c_row0_col0, #T_7309c_row1_col0, #T_7309c_row2_col0, #T_7309c_row3_col0, #T_7309c_row4_col0, #T_7309c_row5_col0, #T_7309c_row6_col0, #T_7309c_row7_col0, #T_7309c_row8_col0, #T_7309c_row9_col0, #T_7309c_row10_col0, #T_7309c_row11_col0 {
#   background-color: #957DAD;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_7309c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7309c_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7309c_level0_row0" class="row_heading level0 row0" >country_name</th>
#       <td id="T_7309c_row0_col0" class="data row0 col0" >427</td>
#     </tr>
#     <tr>
#       <th id="T_7309c_level0_row1" class="row_heading level0 row1" >city_name</th>
#       <td id="T_7309c_row1_col0" class="data row1 col0" >1</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Checking the Duplicate Value**

# %%
print(f'There is {df.duplicated().sum()} duplicate value.')
# Out:
# There is 0 duplicate value.

# %% [markdown]
# **Checking the Unique Value**

# %%
df.nunique().to_frame().style.set_properties(**{"background-color": "#957DAD", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_d0786_row0_col0, #T_d0786_row1_col0, #T_d0786_row2_col0, #T_d0786_row3_col0, #T_d0786_row4_col0, #T_d0786_row5_col0, #T_d0786_row6_col0, #T_d0786_row7_col0, #T_d0786_row8_col0, #T_d0786_row9_col0, #T_d0786_row10_col0, #T_d0786_row11_col0 {
#   background-color: #957DAD;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_d0786">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0786_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0786_level0_row0" class="row_heading level0 row0" >country_name</th>
#       <td id="T_d0786_row0_col0" class="data row0 col0" >175</td>
#     </tr>
#     <tr>
#       <th id="T_d0786_level0_row1" class="row_heading level0 row1" >city_name</th>
#       <td id="T_d0786_row1_col0" class="data row1 col0" >23462</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %% [markdown]
# **Plotting Heatmap for Null Values**

# %%
sns.heatmap(df.isnull(), cmap=sns.cubehelix_palette())
# Out:
# <Axes: >

# %% [markdown]
# **Checking Summary Statistics**

# %%
df.describe().style.set_properties(**{"background-color": "#957DAD", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_30b69_row0_col0, #T_30b69_row0_col1, #T_30b69_row0_col2, #T_30b69_row0_col3, #T_30b69_row0_col4, #T_30b69_row1_col0, #T_30b69_row1_col1, #T_30b69_row1_col2, #T_30b69_row1_col3, #T_30b69_row1_col4, #T_30b69_row2_col0, #T_30b69_row2_col1, #T_30b69_row2_col2, #T_30b69_row2_col3, #T_30b69_row2_col4, #T_30b69_row3_col0, #T_30b69_row3_col1, #T_30b69_row3_col2, #T_30b69_row3_col3, #T_30b69_row3_col4, #T_30b69_row4_col0, #T_30b69_row4_col1, #T_30b69_row4_col2, #T_30b69_row4_col3, #T_30b69_row4_col4, #T_30b69_row5_col0, #T_30b69_row5_col1, #T_30b69_row5_col2, #T_30b69_row5_col3, #T_30b69_row5_col4, #T_30b69_row6_col0, #T_30b69_row6_col1, #T_30b69_row6_col2, #T_30b69_row6_col3, #T_30b69_row6_col4, #T_30b69_row7_col0, #T_30b69_row7_col1, #T_30b69_row7_col2, #T_30b69_row7_col3, #T_30b69_row7_col4 {
#   background-color: #957DAD;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_30b69">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# **Summary Statistics - Categorical Values**

# %%
df.describe(include=['object']).T.style.set_properties(**{"background-color": "#957DAD", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_fd6e5_row0_col0, #T_fd6e5_row0_col1, #T_fd6e5_row0_col2, #T_fd6e5_row0_col3, #T_fd6e5_row1_col0, #T_fd6e5_row1_col1, #T_fd6e5_row1_col2, #T_fd6e5_row1_col3, #T_fd6e5_row2_col0, #T_fd6e5_row2_col1, #T_fd6e5_row2_col2, #T_fd6e5_row2_col3, #T_fd6e5_row3_col0, #T_fd6e5_row3_col1, #T_fd6e5_row3_col2, #T_fd6e5_row3_col3, #T_fd6e5_row4_col0, #T_fd6e5_row4_col1, #T_fd6e5_row4_col2, #T_fd6e5_row4_col3, #T_fd6e5_row5_col0, #T_fd6e5_row5_col1, #T_fd6e5_row5_col2, #T_fd6e5_row5_col3, #T_fd6e5_row6_col0, #T_fd6e5_row6_col1, #T_fd6e5_row6_col2, #T_fd6e5_row6_col3 {
#   background-color: #957DAD;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_fd6e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd6e5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_fd6e5_level0_col1" class="col_heading level0 col1" >unique</th>
# ...

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">EDA: Global Air Pollution</p>

# %% [markdown]
# **Visualize AQI Distribution**

# %%
# Set seaborn style and palette
sns.set_style('whitegrid')
sns.set_palette('magma')

# Plotting
plt.figure(figsize=(12, 6))
sns.histplot(df['aqi_value'], bins=20, kde=True, edgecolor='black')
plt.title('Distribution of AQI Values')
plt.xlabel('AQI Value')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **Pollutant AQI Distribution**

# %%
# Set seaborn style and palette
sns.set_style('whitegrid')
sns.set_palette('magma')

# Plotting
plt.figure(figsize=(12, 8))  # Larger figure size for better visibility
sns.boxplot(data=df[['aqi_value', 'co_aqi_value\t', 'ozone_aqi_value', 'no2_aqi_value', 'pm2.5_aqi_value']])
plt.title('Boxplot of AQI Values', fontsize=16)  # Larger font size for title
plt.ylabel('AQI Value', fontsize=14)  # Adjust font size for y-axis label
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Increase visibility of grid lines and ticks
plt.tick_params(axis='both', which='both', length=5, width=1, labelsize=12)  

plt.show()

# %% [markdown]
# **AQI Value - Top 50 Countries**

# %%
# Set seaborn style to white
sns.set_style("white")

# Calculate average AQI value by country
avg_aqi_by_country = df.groupby('country_name')['aqi_value'].mean().sort_values(ascending=False)

# Select top 50 countries
top_50_countries = avg_aqi_by_country.head(50)

# Plotting
plt.figure(figsize=(12, 8))
sns.barplot(x=top_50_countries.values, y=top_50_countries.index, palette='magma')
plt.title('Top 50 Countries by Average AQI Value')
plt.xlabel('Average AQI Value')
plt.ylabel('Country')
plt.xticks(rotation=45)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# **Correlation Analysis**

# %%
# Calculate correlation matrix
correlation_matrix = df[['aqi_value', 'co_aqi_value\t', 'ozone_aqi_value', 'no2_aqi_value', 'pm2.5_aqi_value']].corr()

# Plot heatmap of correlation matrix
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix, annot=True, cmap='RdPu', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # <p style="padding:20px;background-color:#925C8A;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Fork, Upvote, and Share</p>
