# %% [markdown]
# <a href="https://www.kaggle.com/code/sazidthe1/nobel-prize-analysis?scriptVersionId=164350373" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:175%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Nobel Prize Winners Analysis</p>
#
#
# <p style="text-align:center; ">
# <img src="https://www.nobelprize.org/images/52993-landscape-full-width-2x.jpg" style='width: 900px; height: 450px;'>
# </p>
#
#
# <p style="text-align:justify; ">
#
# <B>The Nobel Prize</B> is a set of prestigious international awards presented annually in several categories, recognizing outstanding contributions in the fields of Physics, Chemistry, Medicine, Literature, Peace, and Economic Sciences. Established by the will of Alfred Nobel, a Swedish inventor, scientist, and philanthropist, in 1895, the prizes are awarded to individuals and organizations that have made significant advancements or contributions to humanity in these areas. The Nobel Prizes are widely regarded as some of the most esteemed honors, celebrating those who have made exceptional strides in promoting knowledge, peace, and positive global impact. The award ceremonies take place on December 10th each year, the anniversary of Alfred Nobel's death, and are accompanied by lectures and events that highlight the laureates' achievements.
#
# Between 1901 and 2023, the Nobel Prizes and the Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel were awarded 621 times to 1,000 people and organisations. With some receiving the Nobel Prize more than once, this makes a total of 965 individuals and 27 organisations. Below, we can view the full list of Nobel Prizes and Nobel Prize laureates. We're going to read in, clean up and visualize the <B>Nobel Prize Winners 🥇</B> Dataset.
# </p>
# <br>
#
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Table of Contents</p>
#
#
# |No  | Contents |No  | Contents  |
# |:---| :---     |:---| :----     |
# |1   | [<font color="#0f4c5c"> Importing Libraries</font>](#1)                   |7  | [<font color="#0f4c5c"> Custom Visualization</font>](#7)       |
# |2   | [<font color="#0f4c5c"> About Dataset</font>](#2)                         |8  | [<font color="#0f4c5c"> USA Dominance</font>](#8)   |
# |3   | [<font color="#0f4c5c"> Basic Exploration</font>](#3)                     |9  | [<font color="#0f4c5c"> A Few More Facts</font>](#9)   |
# |4   | [<font color="#0f4c5c"> Dataset Summary</font>](#4)                       |10 | [<font color="#0f4c5c"> Oldest and Youngest Winners</font>](#10)    |
# |5   | [<font color="#0f4c5c"> Digging Deeper</font>](#5)                        |11 | [<font color="#0f4c5c"> Get a Prize </font>](#11)  |
# |6   | [<font color="#0f4c5c"> Quick Facts</font>](#6)                           |12 | [<font color="#0f4c5c"> Thank You</font>](#12)     |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Data Description</p>
#
# <div style = "color: Black; display: fill;
#               border-radius: 5px;
#               background-color: #00A2A5;
#               font-size: 100%;
#               font-family: Verdana">
#     <p style = "padding: 7px; color: Black;">
#     <ul> 📌 <b>year</b> - The year in which the Nobel Prize was awarded<br>
#          📌 <b>category</b> - The category or field for which the Nobel Prize was awarded<br>
#          📌 <b>motivation</b> - A brief description of the laureate's contributions for which they received the prize<br>
#          📌 <b>prizeShare</b> - Indicates whether the laureate shared the prize with others<br>
#          📌 <b>laureateID</b> - A unique identifier for the laureate<br>
#          📌 <b>fullName</b> - The full name of the laureate<br>
#          📌 <b>gender</b> - The gender of the laureate<br>
#          📌 <b>born</b> - The birthdate of the laureate<br>
#          📌 <b>bornCountry</b> - The country in which the laureate was born<br>
#          📌 <b>bornCity</b> - The city in which the laureate was born<br>
#          📌 <b>died</b> - The date of death of the laureate<br>
#          📌 <b>diedCountry</b> - The country in which the laureate died<br>
#          📌 <b>diedCity</b> - The city in which the laureate died<br>
#          📌 <b>organizationName</b> - The name of the organization which the laureate is associated with<br>
#          📌 <b>organizationCountry</b> - The country in which the associated organization is located<br>
#          📌 <b>organizationCity</b> - The city in which the associated organization is located<br>
#         <br>

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
# Loading required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import warnings
warnings.filterwarnings("ignore")

# %%
# Reading the Nobel Prize data
df = pd.read_csv('/kaggle/input/nobel-prize-data/nobel_laureates_data.csv')

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">About Dataset</p>

# %% [markdown]
# **Let's Have a Glimpse of the Dataset**

# %%
# Taking a look at the first several winners
df.head(n=5).style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %%
# Taking a look at the last several winners
df.tail(n=5).style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Basic Exploration</p>

# %% [markdown]
# **Understanding the Dataset**

# %%
# Checking shape of the dataset
df.shape
# Out:
# (1000, 16)

# %%
# Checking columns present in the dataset
df.columns
# Out:
# Index(['year', 'category', 'motivation', 'prizeShare', 'laureateID',
#        'fullName', 'gender', 'born', 'bornCountry', 'bornCity', 'died',
#        'diedCountry', 'diedCity', 'organizationName', 'organizationCountry',
#        'organizationCity'],
#       dtype='object')

# %%
# Gathering bsic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 1000 non-null   int64
#  1   category             1000 non-null   object
#  2   motivation           1000 non-null   object
#  3   prizeShare           1000 non-null   int64
#  4   laureateID           1000 non-null   int64
#  5   fullName             1000 non-null   object
#  6   gender               1000 non-null   object
#  7   born                 1000 non-null   object
#  8   bornCountry          970 non-null    object
#  9   bornCity             966 non-null    object
#  10  died                 970 non-null    object
#  11  diedCountry          652 non-null    object
#  12  diedCity             646 non-null    object
#  13  organizationName     736 non-null    object
#  14  organizationCountry  733 non-null    object
# ...

# %% [markdown]
# **Checking the Missing Value**

# %%
# Checking if there any Null value present in the dataset
df.isnull().sum().to_frame().T.style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_0d0cb_row0_col0, #T_0d0cb_row0_col1, #T_0d0cb_row0_col2, #T_0d0cb_row0_col3, #T_0d0cb_row0_col4, #T_0d0cb_row0_col5, #T_0d0cb_row0_col6, #T_0d0cb_row0_col7, #T_0d0cb_row0_col8, #T_0d0cb_row0_col9, #T_0d0cb_row0_col10, #T_0d0cb_row0_col11, #T_0d0cb_row0_col12, #T_0d0cb_row0_col13, #T_0d0cb_row0_col14, #T_0d0cb_row0_col15 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_0d0cb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d0cb_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_0d0cb_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_0d0cb_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_0d0cb_level0_col3" class="col_heading level0 col3" >prizeShare</th>
#       <th id="T_0d0cb_level0_col4" class="col_heading level0 col4" >laureateID</th>
# ...

# %%
# Plotting Heatmap for Null Values
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# **Checking the Duplicate Value**

# %%
# Checking if there any duplicate value present in the dataset
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Checking the Unique Value**

# %%
# Checking the number of unique values
df.nunique().to_frame().T.style.set_properties(**{"background-color": "#00A2A5", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_cbad6_row0_col0, #T_cbad6_row0_col1, #T_cbad6_row0_col2, #T_cbad6_row0_col3, #T_cbad6_row0_col4, #T_cbad6_row0_col5, #T_cbad6_row0_col6, #T_cbad6_row0_col7, #T_cbad6_row0_col8, #T_cbad6_row0_col9, #T_cbad6_row0_col10, #T_cbad6_row0_col11, #T_cbad6_row0_col12, #T_cbad6_row0_col13, #T_cbad6_row0_col14, #T_cbad6_row0_col15 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_cbad6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbad6_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_cbad6_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_cbad6_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_cbad6_level0_col3" class="col_heading level0 col3" >prizeShare</th>
#       <th id="T_cbad6_level0_col4" class="col_heading level0 col4" >laureateID</th>
# ...

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:White;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %% [markdown]
# **Data Types of the Features**

# %%
df.dtypes.to_frame().T.style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_07492_row0_col0, #T_07492_row0_col1, #T_07492_row0_col2, #T_07492_row0_col3, #T_07492_row0_col4, #T_07492_row0_col5, #T_07492_row0_col6, #T_07492_row0_col7, #T_07492_row0_col8, #T_07492_row0_col9, #T_07492_row0_col10, #T_07492_row0_col11, #T_07492_row0_col12, #T_07492_row0_col13, #T_07492_row0_col14, #T_07492_row0_col15 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_07492">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_07492_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_07492_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_07492_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_07492_level0_col3" class="col_heading level0 col3" >prizeShare</th>
#       <th id="T_07492_level0_col4" class="col_heading level0 col4" >laureateID</th>
# ...

# %%
# Checking the summary statistics
df.describe().style.set_properties(**{"background-color": "#00A2A5", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_da1da_row0_col0, #T_da1da_row0_col1, #T_da1da_row0_col2, #T_da1da_row1_col0, #T_da1da_row1_col1, #T_da1da_row1_col2, #T_da1da_row2_col0, #T_da1da_row2_col1, #T_da1da_row2_col2, #T_da1da_row3_col0, #T_da1da_row3_col1, #T_da1da_row3_col2, #T_da1da_row4_col0, #T_da1da_row4_col1, #T_da1da_row4_col2, #T_da1da_row5_col0, #T_da1da_row5_col1, #T_da1da_row5_col2, #T_da1da_row6_col0, #T_da1da_row6_col1, #T_da1da_row6_col2, #T_da1da_row7_col0, #T_da1da_row7_col1, #T_da1da_row7_col2 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_da1da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da1da_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_da1da_level0_col1" class="col_heading level0 col1" >prizeShare</th>
#       <th id="T_da1da_level0_col2" class="col_heading level0 col2" >laureateID</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Display summary statistics for categorical columns
df.describe(include="object").style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Digging Deeper</p>

# %% [markdown]
# **Gender Distribution of Prize Winners**

# %%
# Filter the DataFrame for 'male' and 'female' genders
gender_df = df[df['gender'].isin(['male', 'female'])]

# Set a color palette for the countplot
palette = "viridis"

# Countplot of Nobel Prize distribution by gender
plt.figure(figsize=(8, 4))
ax = sns.countplot(x='gender', data=gender_df, palette=palette)

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title('Gender Distribution of Nobel Prize Winners', fontsize=16)
plt.xlabel('Gender', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# **Nobel Prize Distribution Over Years**

# %%
# Define a style dictionary
plot_style_line = {
    'color': 'darkblue',
    'marker': 'o',
    'markersize': 8,
    'linestyle': '-',
    'linewidth': 2,
    'title': {'text': 'Nobel Prize Distribution Over Years', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Year', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Prize Share', 'fontsize': 14, 'color': 'gray'},
    'grid': {'axis': 'both', 'linestyle': '--', 'alpha': 0.5, 'color': 'gray'}
}

# Line plot of Nobel Prize distribution over years with styling
plt.figure(figsize=(14, 6))
sns.lineplot(x='year', y='prizeShare', data=df, color=plot_style_line['color'], marker=plot_style_line['marker'],
             markersize=plot_style_line['markersize'], linestyle=plot_style_line['linestyle'],
             linewidth=plot_style_line['linewidth'])

# Title and labels
plt.title(plot_style_line['title']['text'], fontsize=plot_style_line['title']['fontsize'], color=plot_style_line['title']['color'])
plt.xlabel(plot_style_line['xlabel']['text'], fontsize=plot_style_line['xlabel']['fontsize'], color=plot_style_line['xlabel']['color'])
plt.ylabel(plot_style_line['ylabel']['text'], fontsize=plot_style_line['ylabel']['fontsize'], color=plot_style_line['ylabel']['color'])

# Add grid lines for better visibility
plt.grid(axis=plot_style_line['grid']['axis'], linestyle=plot_style_line['grid']['linestyle'],
         alpha=plot_style_line['grid']['alpha'], color=plot_style_line['grid']['color'])

# Show the plot
plt.show()

# %% [markdown]
# **Nobel Prize Distribution by Category**

# %%
# Set a color palette for the countplot
palette = "viridis"

# Countplot of Nobel Prize distribution by category
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='category', data=df, order=df['category'].value_counts().index, palette=palette)

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Title and labels
plt.title('Nobel Prize Distribution by Category', fontsize=16)
plt.xlabel('Category', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Time Trends in Different Categories**

# %%
# Set a color palette for the line plots
palette = "viridis"

# Line plots of Nobel Prize distribution over years for each category with styling
g = sns.FacetGrid(df, col='category', col_wrap=4, height=4, palette=palette)
g.map(sns.lineplot, 'year', 'prizeShare', linewidth=2)

# Set titles for each facet
g.set_titles(col_template="{col_name}", fontsize=16, color='darkblue')

# Set overall title
g.fig.suptitle('Time Trends in Nobel Prize Distribution by Category', y=1.02, fontsize=20, color='darkblue')

# Set axis labels
g.set_axis_labels('Year', 'Prize Share', fontsize=14, color='gray')

# Add legend for each facet
for ax in g.axes.flat:
    ax.legend(title='Category', title_fontsize='12', fontsize='10', loc='upper right')

# Add grid lines for better visibility
g.fig.tight_layout(rect=[0, 0, 1, 0.96])
g.fig.subplots_adjust(top=0.9)
g.despine(left=True, bottom=True)

# Show the plots
plt.show()

# %% [markdown]
# **Winners Born Country and City**

# %%
# Define a style dictionary
plot_style_countplot = {
    'palette': 'viridis',
    'title': {'text': 'Nobel Prize Winners by Born Country', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Born Country', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 45,
    'grid': {'axis': 'y', 'linestyle': '--', 'alpha': 0.5, 'color': 'gray'}
}

# Countplot of Nobel Prize winners based on born country with styling
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='bornCountry', data=df, order=df['bornCountry'].value_counts().index, palette=plot_style_countplot['palette'])

# Title and labels
plt.title(plot_style_countplot['title']['text'], fontsize=plot_style_countplot['title']['fontsize'], color=plot_style_countplot['title']['color'])
plt.xlabel(plot_style_countplot['xlabel']['text'], fontsize=plot_style_countplot['xlabel']['fontsize'], color=plot_style_countplot['xlabel']['color'])
plt.ylabel(plot_style_countplot['ylabel']['text'], fontsize=plot_style_countplot['ylabel']['fontsize'], color=plot_style_countplot['ylabel']['color'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=plot_style_countplot['xticks_rotation'], ha="right")

# Add grid lines for better visibility
plt.grid(axis=plot_style_countplot['grid']['axis'], linestyle=plot_style_countplot['grid']['linestyle'],
         alpha=plot_style_countplot['grid']['alpha'], color=plot_style_countplot['grid']['color'])

# Show the plot
plt.show()

# %%
# Define a style dictionary
plot_style_countplot_top_cities = {
    'palette': 'viridis',
    'title': {'text': 'Top 50 Born City of Nobel Prize Winners', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Born City', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 45,
    'grid': {'axis': 'y', 'linestyle': '--', 'alpha': 0.5, 'color': 'gray'}
}

# Get the top 50 cities with the most Nobel Prize winners
top_cities = df['bornCity'].value_counts().head(50)

# Countplot of Nobel Prize winners based on born city (top 50) with styling and numbers on top
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='bornCity', data=df, order=top_cities.index, palette=plot_style_countplot_top_cities['palette'])

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_countplot_top_cities['title']['text'], fontsize=plot_style_countplot_top_cities['title']['fontsize'], color=plot_style_countplot_top_cities['title']['color'])
plt.xlabel(plot_style_countplot_top_cities['xlabel']['text'], fontsize=plot_style_countplot_top_cities['xlabel']['fontsize'], color=plot_style_countplot_top_cities['xlabel']['color'])
plt.ylabel(plot_style_countplot_top_cities['ylabel']['text'], fontsize=plot_style_countplot_top_cities['ylabel']['fontsize'], color=plot_style_countplot_top_cities['ylabel']['color'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=plot_style_countplot_top_cities['xticks_rotation'], ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Organization that Winners Associated With**

# %%
# Define a style dictionary
plot_style_countplot_organizations = {
    'palette': 'viridis',
    'title': {'text': 'Top 30 Organizations of Nobel Prize Winners', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Organization Name', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 45
}

# Countplot of Nobel Prizes distributed by organization (top 30) with styling and numbers on top
top_organizations = df['organizationName'].value_counts().head(30)

plt.figure(figsize=(12, 6))
ax = sns.countplot(x='organizationName', data=df, order=top_organizations.index, palette=plot_style_countplot_organizations['palette'])

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_countplot_organizations['title']['text'], fontsize=plot_style_countplot_organizations['title']['fontsize'], color=plot_style_countplot_organizations['title']['color'])
plt.xlabel(plot_style_countplot_organizations['xlabel']['text'], fontsize=plot_style_countplot_organizations['xlabel']['fontsize'], color=plot_style_countplot_organizations['xlabel']['color'])
plt.ylabel(plot_style_countplot_organizations['ylabel']['text'], fontsize=plot_style_countplot_organizations['ylabel']['fontsize'], color=plot_style_countplot_organizations['ylabel']['color'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=plot_style_countplot_organizations['xticks_rotation'], ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Organization Country Distribution**

# %%
# Define a style dictionary
plot_style_countplot_org_country = {
    'palette': 'viridis',
    'title': {'text': 'Nobel Prizes Distribution by Organization Country', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Organization Country', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 45
}

# Countplot of Nobel Prizes distributed by organization country with styling
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='organizationCountry', data=df, order=df['organizationCountry'].value_counts().index, palette=plot_style_countplot_org_country['palette'])

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_countplot_org_country['title']['text'], fontsize=plot_style_countplot_org_country['title']['fontsize'], color=plot_style_countplot_org_country['title']['color'])
plt.xlabel(plot_style_countplot_org_country['xlabel']['text'], fontsize=plot_style_countplot_org_country['xlabel']['fontsize'], color=plot_style_countplot_org_country['xlabel']['color'])
plt.ylabel(plot_style_countplot_org_country['ylabel']['text'], fontsize=plot_style_countplot_org_country['ylabel']['fontsize'], color=plot_style_countplot_org_country['ylabel']['color'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=plot_style_countplot_org_country['xticks_rotation'], ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Investigate Died Information**

# %%
# Define a style dictionary for died country countplot
plot_style_countplot_died_country = {
    'palette': 'viridis',
    'title': {'text': 'Nobel Prize Winners by Died Country', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Died Country', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 45
}

# Countplot of Nobel Prize winners based on died country with styling
plt.figure(figsize=(16, 6))
ax = sns.countplot(x='diedCountry', data=df, order=df['diedCountry'].value_counts().index, palette=plot_style_countplot_died_country['palette'])

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', xytext=(0, 10), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_countplot_died_country['title']['text'], fontsize=plot_style_countplot_died_country['title']['fontsize'], color=plot_style_countplot_died_country['title']['color'])
plt.xlabel(plot_style_countplot_died_country['xlabel']['text'], fontsize=plot_style_countplot_died_country['xlabel']['fontsize'], color=plot_style_countplot_died_country['xlabel']['color'])
plt.ylabel(plot_style_countplot_died_country['ylabel']['text'], fontsize=plot_style_countplot_died_country['ylabel']['fontsize'], color=plot_style_countplot_died_country['ylabel']['color'])

# Rotate x-axis labels for better readability
plt.xticks(rotation=plot_style_countplot_died_country['xticks_rotation'], ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Motivation Text**

# %%
# Generate a word cloud for motivation text
motivation_text = ' '.join(df['motivation'])
wordcloud = WordCloud(width=800, height=400, random_state=21, max_font_size=110).generate(motivation_text)

plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('Motivation Word Cloud')
plt.show()

# %% [markdown]
# **Motivation Sentiment Analysis**

# %%
from textblob import TextBlob  # Import TextBlob

# Set a color palette for the scatter plot
palette = "viridis"

# Sentiment analysis of motivation text
df['motivation_sentiment'] = df['motivation'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# Scatter plot of motivation sentiment over years with styling
plt.figure(figsize=(14, 6))
sns.scatterplot(x='year', y='motivation_sentiment', data=df, palette=palette, alpha=0.7)

# Title and labels
plt.title('Motivation Sentiment Over Years', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Motivation Sentiment', fontsize=14)

# Add grid lines for better visibility
plt.grid(axis='both', linestyle='--', alpha=0.5, color='lightgray')

# Show the plot
plt.show()

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Quick Facts</p>

# %% [markdown]
# **Top 10 Nationalities**

# %%
# Get the top 10 born countries with the most Nobel Prize winners
top_born_countries = df['bornCountry'].value_counts().head(10)

# Define a style dictionary for the horizontal bar plot
plot_style_horizontal_bar_top_born_countries = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Nationalities with the Most Nobel Prize Winners', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Born Country', 'fontsize': 14, 'color': 'gray'}
}

# Horizontal bar plot of top 10 born countries with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_born_countries.values, y=top_born_countries.index, palette=plot_style_horizontal_bar_top_born_countries['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_horizontal_bar_top_born_countries['title']['text'], fontsize=plot_style_horizontal_bar_top_born_countries['title']['fontsize'], color=plot_style_horizontal_bar_top_born_countries['title']['color'])
plt.xlabel(plot_style_horizontal_bar_top_born_countries['xlabel']['text'], fontsize=plot_style_horizontal_bar_top_born_countries['xlabel']['fontsize'], color=plot_style_horizontal_bar_top_born_countries['xlabel']['color'])
plt.ylabel(plot_style_horizontal_bar_top_born_countries['ylabel']['text'], fontsize=plot_style_horizontal_bar_top_born_countries['ylabel']['fontsize'], color=plot_style_horizontal_bar_top_born_countries['ylabel']['color'])

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Born Cities**

# %%
# Define a style dictionary without grid lines
plot_style_top_cities_horizontal = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Born Cities with the Most Nobel Prize Winners', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Born City', 'fontsize': 14, 'color': 'gray'}
}

# Get the top 10 cities with the most Nobel Prize winners
top_cities = df['bornCity'].value_counts().head(10)

# Horizontal bar plot of top 10 born cities with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_cities.values, y=top_cities.index, palette=plot_style_top_cities_horizontal['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_top_cities_horizontal['title']['text'], fontsize=plot_style_top_cities_horizontal['title']['fontsize'], color=plot_style_top_cities_horizontal['title']['color'])
plt.xlabel(plot_style_top_cities_horizontal['xlabel']['text'], fontsize=plot_style_top_cities_horizontal['xlabel']['fontsize'], color=plot_style_top_cities_horizontal['xlabel']['color'])
plt.ylabel(plot_style_top_cities_horizontal['ylabel']['text'], fontsize=plot_style_top_cities_horizontal['ylabel']['fontsize'], color=plot_style_top_cities_horizontal['ylabel']['color'])

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Oganizations of Nobel Prize Winners Associated With**

# %%
# Get the top 10 organizations with the most Nobel Prize winners
top_organizations = df['organizationName'].value_counts().head(10)

# Define a style dictionary for the horizontal bar plot
plot_style_horizontal_bar_top_organizations = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Organizations with the Most Nobel Prize Winners', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Organization', 'fontsize': 14, 'color': 'gray'}
}

# Horizontal bar plot of top 10 organizations with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_organizations.values, y=top_organizations.index, palette=plot_style_horizontal_bar_top_organizations['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_horizontal_bar_top_organizations['title']['text'], fontsize=plot_style_horizontal_bar_top_organizations['title']['fontsize'], color=plot_style_horizontal_bar_top_organizations['title']['color'])
plt.xlabel(plot_style_horizontal_bar_top_organizations['xlabel']['text'], fontsize=plot_style_horizontal_bar_top_organizations['xlabel']['fontsize'], color=plot_style_horizontal_bar_top_organizations['xlabel']['color'])
plt.ylabel(plot_style_horizontal_bar_top_organizations['ylabel']['text'], fontsize=plot_style_horizontal_bar_top_organizations['ylabel']['fontsize'], color=plot_style_horizontal_bar_top_organizations['ylabel']['color'])

# Remove grid lines
ax.xaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Oganization Location (Cities)**

# %%
# Define a style dictionary without grid lines
plot_style_top_org_cities = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Nobel Prize Winners by Organization City', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Organization City', 'fontsize': 14, 'color': 'gray'},
    'xticks_rotation': 0
}

# Get the top 10 cities with the most Nobel Prize winners (organization city)
top_org_cities = df['organizationCity'].value_counts().head(10)

# Horizontal bar plot of top 10 Nobel Prize winners based on organization city with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_org_cities.values, y=top_org_cities.index, palette=plot_style_top_org_cities['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_top_org_cities['title']['text'], fontsize=plot_style_top_org_cities['title']['fontsize'], color=plot_style_top_org_cities['title']['color'])
plt.xlabel(plot_style_top_org_cities['xlabel']['text'], fontsize=plot_style_top_org_cities['xlabel']['fontsize'], color=plot_style_top_org_cities['xlabel']['color'])
plt.ylabel(plot_style_top_org_cities['ylabel']['text'], fontsize=plot_style_top_org_cities['ylabel']['fontsize'], color=plot_style_top_org_cities['ylabel']['color'])

# Remove grid lines
ax.xaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Countries Where Most of the Nobel Prize Winners Died**

# %%
# Get the top 10 countries where Nobel Prize winners died
top_died_countries = df['diedCountry'].value_counts().head(10)

# Define a style dictionary for the horizontal bar plot
plot_style_horizontal_bar_top_died_countries = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Countries where Nobel Prize Winners Died', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Died Country', 'fontsize': 14, 'color': 'gray'}
}

# Horizontal bar plot of top 10 countries where Nobel Prize winners died with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_died_countries.values, y=top_died_countries.index, palette=plot_style_horizontal_bar_top_died_countries['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_horizontal_bar_top_died_countries['title']['text'], fontsize=plot_style_horizontal_bar_top_died_countries['title']['fontsize'], color=plot_style_horizontal_bar_top_died_countries['title']['color'])
plt.xlabel(plot_style_horizontal_bar_top_died_countries['xlabel']['text'], fontsize=plot_style_horizontal_bar_top_died_countries['xlabel']['fontsize'], color=plot_style_horizontal_bar_top_died_countries['xlabel']['color'])
plt.ylabel(plot_style_horizontal_bar_top_died_countries['ylabel']['text'], fontsize=plot_style_horizontal_bar_top_died_countries['ylabel']['fontsize'], color=plot_style_horizontal_bar_top_died_countries['ylabel']['color'])

# Remove grid lines
ax.xaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Cities Where Most of the Nobel Prize Winners Died**

# %%
# Get the top 10 cities where Nobel Prize winners died
top_died_cities = df['diedCity'].value_counts().head(10)

# Define a style dictionary for the horizontal bar plot
plot_style_horizontal_bar_top_died_cities = {
    'palette': 'viridis',
    'title': {'text': 'Top 10 Cities where Nobel Prize Winners Died', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Count', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Died City', 'fontsize': 14, 'color': 'gray'}
}

# Horizontal bar plot of top 10 cities where Nobel Prize winners died with styling and numbers on the bars
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_died_cities.values, y=top_died_cities.index, palette=plot_style_horizontal_bar_top_died_cities['palette'])

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{p.get_width()}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

# Title and labels
plt.title(plot_style_horizontal_bar_top_died_cities['title']['text'], fontsize=plot_style_horizontal_bar_top_died_cities['title']['fontsize'], color=plot_style_horizontal_bar_top_died_cities['title']['color'])
plt.xlabel(plot_style_horizontal_bar_top_died_cities['xlabel']['text'], fontsize=plot_style_horizontal_bar_top_died_cities['xlabel']['fontsize'], color=plot_style_horizontal_bar_top_died_cities['xlabel']['color'])
plt.ylabel(plot_style_horizontal_bar_top_died_cities['ylabel']['text'], fontsize=plot_style_horizontal_bar_top_died_cities['ylabel']['fontsize'], color=plot_style_horizontal_bar_top_died_cities['ylabel']['color'])

# Remove grid lines
ax.xaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Custom Visualization</p>

# %% [markdown]
# **Nobel Prize Categories Distribution**

# %%
# Get the distribution of Nobel Prize categories
category_distribution = df['category'].value_counts()

# Define a custom color palette
custom_palette = ["#66b3ff", "#99ff99", "#ffcc99", "#c2c2f0", "#ffb3e6", "#c2f0c2"]

# Define a style dictionary for the pie chart
plot_style_pie_chart = {
    'title': {'text': 'Nobel Prize Categories Distribution', 'fontsize': 16, 'color': 'darkblue'}
}

# Pie chart of Nobel Prize categories distribution with custom styling
plt.figure(figsize=(10, 10))
plt.pie(category_distribution, labels=category_distribution.index, autopct='%1.1f%%', startangle=140, colors=custom_palette)
plt.title(plot_style_pie_chart['title']['text'], fontsize=plot_style_pie_chart['title']['fontsize'], color=plot_style_pie_chart['title']['color'])
plt.show()

# %% [markdown]
# **Nobel Prize Winners Over Time by Gender**

# %%
# Define a style dictionary for the line plot
plot_style_lineplot_gender = {
    'palette': {'male': 'dodgerblue', 'female': 'orchid'},
    'title': {'text': 'Nobel Prize Winners Over Time by Gender', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Year', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Prize Share', 'fontsize': 14, 'color': 'gray'},
    'title_male': {'text': 'Nobel Prize Winners Over Time - Male', 'fontsize': 16, 'color': 'darkblue'},
    'title_female': {'text': 'Nobel Prize Winners Over Time - Female', 'fontsize': 16, 'color': 'darkred'}
}

# Filter the DataFrame for 'male' gender
male_df = df[df['gender'] == 'male']

# Line plot of Nobel Prize winners over time for males with styling
plt.figure(figsize=(16, 8))
sns.lineplot(x='year', y='prizeShare', data=male_df, estimator=None, lw=2, color=plot_style_lineplot_gender['palette']['male'])

# Title and labels
plt.title(plot_style_lineplot_gender['title_male']['text'], fontsize=plot_style_lineplot_gender['title_male']['fontsize'], color=plot_style_lineplot_gender['title_male']['color'])
plt.xlabel(plot_style_lineplot_gender['xlabel']['text'], fontsize=plot_style_lineplot_gender['xlabel']['fontsize'], color=plot_style_lineplot_gender['xlabel']['color'])
plt.ylabel(plot_style_lineplot_gender['ylabel']['text'], fontsize=plot_style_lineplot_gender['ylabel']['fontsize'], color=plot_style_lineplot_gender['ylabel']['color'])

# Add grid lines for better visibility
plt.grid(axis='both', linestyle='--', alpha=0.5, color='lightgray')

# Show the plot
plt.show()

# Filter the DataFrame for 'female' gender
female_df = df[df['gender'] == 'female']

# Line plot of Nobel Prize winners over time for females with styling
plt.figure(figsize=(16, 8))
sns.lineplot(x='year', y='prizeShare', data=female_df, estimator=None, lw=2, color=plot_style_lineplot_gender['palette']['female'])

# Title and labels
plt.title(plot_style_lineplot_gender['title_female']['text'], fontsize=plot_style_lineplot_gender['title_female']['fontsize'], color=plot_style_lineplot_gender['title_female']['color'])
plt.xlabel(plot_style_lineplot_gender['xlabel']['text'], fontsize=plot_style_lineplot_gender['xlabel']['fontsize'], color=plot_style_lineplot_gender['xlabel']['color'])
plt.ylabel(plot_style_lineplot_gender['ylabel']['text'], fontsize=plot_style_lineplot_gender['ylabel']['fontsize'], color=plot_style_lineplot_gender['ylabel']['color'])

# Add grid lines for better visibility
plt.grid(axis='both', linestyle='--', alpha=0.5, color='lightgray')

# Show the plot
plt.show()

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">USA Dominance</p>

# %%
# Display the number of prizes won by the top 10 nationalities.
df['bornCountry'].value_counts().head(10)
# Out:
# bornCountry
# USA               292
# United Kingdom     90
# Germany            84
# France             61
# Sweden             30
# Poland             29
# Russia             29
# Japan              28
# Canada             21
# Italy              20
# Name: count, dtype: int64

# %% [markdown]
# <p> This is not so surprising perhaps: the most common Nobel laureate between 1901 and 2023 was a man born in the United States of America. But in 1901 all the winners were European. When did the USA start to dominate the Nobel Prize charts?</p>

# %% [markdown]
# **Poportion of USA Dominance Over Decades**

# %%
# Calculating the proportion of USA born winners per decade
df['usa_born_winner'] = df['bornCountry'] == 'USA'
df['decade'] = (np.floor(df['year']/10) * 10).astype(int)
prop_usa_winners = df.groupby('decade', as_index=False)['usa_born_winner'].mean()

# Display the proportions of USA born winners per decade
prop_usa_winners.style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_ae669_row0_col0, #T_ae669_row0_col1, #T_ae669_row1_col0, #T_ae669_row1_col1, #T_ae669_row2_col0, #T_ae669_row2_col1, #T_ae669_row3_col0, #T_ae669_row3_col1, #T_ae669_row4_col0, #T_ae669_row4_col1, #T_ae669_row5_col0, #T_ae669_row5_col1, #T_ae669_row6_col0, #T_ae669_row6_col1, #T_ae669_row7_col0, #T_ae669_row7_col1, #T_ae669_row8_col0, #T_ae669_row8_col1, #T_ae669_row9_col0, #T_ae669_row9_col1, #T_ae669_row10_col0, #T_ae669_row10_col1, #T_ae669_row11_col0, #T_ae669_row11_col1, #T_ae669_row12_col0, #T_ae669_row12_col1 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_ae669">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae669_level0_col0" class="col_heading level0 col0" >decade</th>
#       <th id="T_ae669_level0_col1" class="col_heading level0 col1" >usa_born_winner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# Setting the plotting theme
sns.set()
# and setting the size of all plots
plt.rcParams['figure.figsize'] = [11, 7]

# Plotting USA born winners 
ax = sns.lineplot(x='decade', y='usa_born_winner', data=prop_usa_winners, color='green', marker='o', markersize=8, linestyle='-', linewidth=2)

# Adding %-formatting to the y-axis
from matplotlib.ticker import PercentFormatter
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# Adding labels and title
plt.xlabel('Decade', fontsize=14, color='gray')
plt.ylabel('Proportion of USA Born Winners', fontsize=14, color='gray')
plt.title('Proportion of USA Born Nobel Prize Winners Over Decades', fontsize=16, color='darkblue')

# Show the plot
plt.show()

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">A Few More Facts</p>

# %% [markdown]
# **Gender of a Typical Nobel Prize Winners**

# %%
# Calculating the proportion of female laureates per decade
df['female_winner'] = df['gender'] == 'female'
prop_female_winners = df.groupby(['decade', 'category'], as_index=False)['female_winner'].mean()

# Define a style dictionary for the line plot
plot_style_lineplot_female = {
    'palette': 'viridis',
    'title': {'text': 'Proportion of Female Laureates Over Time by Category', 'fontsize': 16, 'color': 'darkblue'},
    'xlabel': {'text': 'Decade', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Proportion of Female Laureates', 'fontsize': 14, 'color': 'gray'}
}

# Plotting USA born winners with % winners on the y-axis 
plt.figure(figsize=(14, 8))
ax = sns.lineplot(x='decade', y='female_winner', hue='category', data=prop_female_winners, palette=plot_style_lineplot_female['palette'])

# Title and labels
plt.title(plot_style_lineplot_female['title']['text'], fontsize=plot_style_lineplot_female['title']['fontsize'], color=plot_style_lineplot_female['title']['color'])
plt.xlabel(plot_style_lineplot_female['xlabel']['text'], fontsize=plot_style_lineplot_female['xlabel']['fontsize'], color=plot_style_lineplot_female['xlabel']['color'])
plt.ylabel(plot_style_lineplot_female['ylabel']['text'], fontsize=plot_style_lineplot_female['ylabel']['fontsize'], color=plot_style_lineplot_female['ylabel']['color'])

# Adding %-formatting to the y-axis
ax.yaxis.set_major_formatter(PercentFormatter(1.0))

# Show the legend
plt.legend(title='Category')

# Add grid lines for better visibility
plt.grid(axis='both', linestyle='--', alpha=0.5, color='lightgray')

# Show the plot
plt.show()

# %% [markdown]
# **The First Woman who Wins the Prize**

# %%
# Picking out the first woman to win a Nobel Prize
df[df.gender == 'female'].nsmallest(1, 'year').style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_d6685_row0_col0, #T_d6685_row0_col1, #T_d6685_row0_col2, #T_d6685_row0_col3, #T_d6685_row0_col4, #T_d6685_row0_col5, #T_d6685_row0_col6, #T_d6685_row0_col7, #T_d6685_row0_col8, #T_d6685_row0_col9, #T_d6685_row0_col10, #T_d6685_row0_col11, #T_d6685_row0_col12, #T_d6685_row0_col13, #T_d6685_row0_col14, #T_d6685_row0_col15, #T_d6685_row0_col16, #T_d6685_row0_col17, #T_d6685_row0_col18, #T_d6685_row0_col19 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_d6685">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6685_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_d6685_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_d6685_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_d6685_level0_col3" class="col_heading level0 col3" >prizeShare</th>
# ...

# %% [markdown]
# **Repeat Nobel Winners**

# %%
# Selecting the laureates that have received 2 or more prizes.
df.groupby('fullName').filter(lambda group: len(group) >= 2).style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# **Age of Winners get their Prize**

# %%
# Converting 'born' column to datetime, handling errors by setting invalid dates to NaT
df['born'] = pd.to_datetime(df['born'], errors='coerce', dayfirst=True)

# Dropping rows with NaT values in 'born' column
df = df.dropna(subset=['born'])

# Calculating the age of Nobel Prize winners
df['age'] = df['year'] - df['born'].dt.year

# Plotting the age of Nobel Prize winners
sns.lmplot(x='year', y='age', data=df, lowess=True, 
           aspect=2, line_kws={'color' : 'orange'})

# Adding the title
plt.title('Age of Nobel Prize Winners Over Time', fontsize=16, color='darkblue')

# Show the plot
plt.show()

# %% [markdown]
# **Age of Nobel Winners by Categories**

# %%
# Same plot as above, but separate plots for each type of Nobel Prize
sns.lmplot(x='year', y='age', row='category', data=df, lowess=True, 
           aspect=2, line_kws={'color' : 'green'})

# Adding the title to the entire set of subplots
plt.suptitle('Age of Nobel Prize Winners Over Time by Category', fontsize=16, color='darkblue')

# Show the plot
plt.show()

# %% [markdown]
# <a id="10"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Oldest and Youngest Winners</p>

# %% [markdown]
# **The Most Oldest Male and Female Winners**

# %%
# Display the oldest male winner
oldest_male_winner = df[df['gender'] == 'male'].nlargest(1, 'age').style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
display(oldest_male_winner)

# Display the oldest female winner
oldest_female_winner = df[df['gender'] == 'female'].nlargest(1, 'age').style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
display(oldest_female_winner)
# Out:
# <style type="text/css">
# #T_dc90b_row0_col0, #T_dc90b_row0_col1, #T_dc90b_row0_col2, #T_dc90b_row0_col3, #T_dc90b_row0_col4, #T_dc90b_row0_col5, #T_dc90b_row0_col6, #T_dc90b_row0_col7, #T_dc90b_row0_col8, #T_dc90b_row0_col9, #T_dc90b_row0_col10, #T_dc90b_row0_col11, #T_dc90b_row0_col12, #T_dc90b_row0_col13, #T_dc90b_row0_col14, #T_dc90b_row0_col15, #T_dc90b_row0_col16, #T_dc90b_row0_col17, #T_dc90b_row0_col18, #T_dc90b_row0_col19, #T_dc90b_row0_col20 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_dc90b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc90b_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_dc90b_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_dc90b_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_dc90b_level0_col3" class="col_heading level0 col3" >prizeShare</th>
# ...

# %% [markdown]
# **The Most Youngest Male and Female Winners**

# %%
# Display the oldest male winner
youngest_male_winner = df[df['gender'] == 'male'].nsmallest(1, 'age').style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
display(youngest_male_winner)

# Display the oldest female winner
youngest_female_winner = df[df['gender'] == 'female'].nsmallest(1, 'age').style.set_properties(**{"background-color": "#00A2A5","color":"white","border": "1.5px  solid black"})
display(youngest_female_winner)
# Out:
# <style type="text/css">
# #T_a5641_row0_col0, #T_a5641_row0_col1, #T_a5641_row0_col2, #T_a5641_row0_col3, #T_a5641_row0_col4, #T_a5641_row0_col5, #T_a5641_row0_col6, #T_a5641_row0_col7, #T_a5641_row0_col8, #T_a5641_row0_col9, #T_a5641_row0_col10, #T_a5641_row0_col11, #T_a5641_row0_col12, #T_a5641_row0_col13, #T_a5641_row0_col14, #T_a5641_row0_col15, #T_a5641_row0_col16, #T_a5641_row0_col17, #T_a5641_row0_col18, #T_a5641_row0_col19, #T_a5641_row0_col20 {
#   background-color: #00A2A5;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_a5641">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5641_level0_col0" class="col_heading level0 col0" >year</th>
#       <th id="T_a5641_level0_col1" class="col_heading level0 col1" >category</th>
#       <th id="T_a5641_level0_col2" class="col_heading level0 col2" >motivation</th>
#       <th id="T_a5641_level0_col3" class="col_heading level0 col3" >prizeShare</th>
# ...

# %%
# Filter for individual laureates with valid age entries and sort by age in descending order
oldest_individual_laureates = df[(df['age'].notnull()) & (df['gender'].isin(['male', 'female']))].sort_values('age', ascending=False).head(10)

# Horizontal Bar Plot of Top 10 Oldest Individual Nobel Prize Laureates
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='age', y='fullName', data=oldest_individual_laureates, palette='viridis')

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

plt.title('Top 10 Oldest Individual Nobel Prize Laureates')
plt.xlabel('Age')
plt.ylabel('Laureate')
plt.show()

# %%
# Filter for individual laureates with valid age entries and sort by age
youngest_individual_laureates = df[(df['age'].notnull()) & (df['gender'].isin(['male', 'female']))].sort_values('age').head(10)

# Horizontal Bar Plot of Top 10 Youngest Individual Nobel Prize Laureates
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='age', y='fullName', data=youngest_individual_laureates, palette='viridis')

# Display values on the bars
for p in ax.patches:
    ax.annotate(f'{int(p.get_width())}', (p.get_width(), p.get_y() + p.get_height() / 2.), 
                ha='left', va='center', xytext=(10, 0), textcoords='offset points',
                fontsize=12, color='black')  # Adjust font size and color

plt.title('Top 10 Youngest Individual Nobel Prize Laureates')
plt.xlabel('Age')
plt.ylabel('Laureate')
plt.show()

# %% [markdown]
# <a id="11"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Get a Prize</p>

# %% [markdown]
# <p><img style="float: right;margin:20px 20px 20px 20px; max-width:200px" src="https://assets.datacamp.com/production/project_441/img/paint_nobel_prize.png"></p>
#
# ### <p>You get a prize for making it to the very end of this notebook!</p>
#
# <p>It might not be a Nobel Prize, but I made it myself in paint so it should count for something. But don't despair, Leonid Hurwicz was 90 years old when he got his prize, so it might not be too late for you.</p>
#
# ### <p>Who knows!</p>

# %% [markdown]
# <a id="12"></a>
# # <p style="padding:10px;background-color:orange;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Thank You!</p>
#
# # <p style="padding:10px;background-color:sky;margin:0;color:#336699;font-family:newtimeroman;font-size:105%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">If you liked this notebook, please upvote 🔼</p>
