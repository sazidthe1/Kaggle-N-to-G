# %% [markdown]
# <a href="https://www.kaggle.com/code/sazidthe1/world-population-analysis?scriptVersionId=164351344" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:175%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">World Population Analysis</p>
#
#
#
# <p style="text-align:center; ">
# <img src="https://img.freepik.com/free-photo/people-world-map-high-angle_23-2149407884.jpg" style='width: 1000px; height: 600px;'>
# </p>
#
#
# <p style="text-align:justify; ">
#
# The world population, currently exceeding 7.9 billion people, represents the dynamic tapestry of humanity spread across continents and cultures. Shaped by diverse histories, languages, and traditions, this global community is intricately connected through a web of social, economic, and technological networks. The demographic landscape is marked by variations in age, gender, and socio-economic status, influencing the distribution of resources and opportunities. As our planet grapples with issues such as sustainability, healthcare, and inequality, understanding the complexities of the world population is essential for addressing global challenges and fostering a more inclusive and collaborative future. In the face of rapid urbanization, technological advancements, and environmental concerns, the evolving dynamics of the world population underscore the need for thoughtful consideration and collective efforts to ensure a balanced and sustainable coexistence for generations to come.
# </p>
# <br>
#
#
# <a id='top'></a>
# <div class="list-group" id="list-tab" role="tablist">
#
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:100">Table of Contents</p>
#
#
# |No  | Contents |No  | Contents  |
# |:---| :---     |:---| :----     |
# |1   | [<font color="#0f4c5c"> Importing Libraries</font>](#1)                   |6  | [<font color="#0f4c5c"> Population Facts</font>](#6)   |
# |2   | [<font color="#0f4c5c"> Dataset Description</font>](#2)                   |7  | [<font color="#0f4c5c"> World Population</font>](#7)   |
# |3   | [<font color="#0f4c5c"> Basic Exploration</font>](#3)                     |8  | [<font color="#0f4c5c"> A Few More Facts</font>](#8)   |
# |4   | [<font color="#0f4c5c"> Dataset Summary</font>](#4)                       |9  | [<font color="#0f4c5c"> Thank You</font>](#9)   |
# |5   | [<font color="#0f4c5c"> Population Across Continent</font>](#5)

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">1. Importing Libraries</p>

# %%
# Loading required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
from wordcloud import WordCloud, STOPWORDS
import warnings
warnings.filterwarnings("ignore")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# Reading the data
df = pd.read_csv('/kaggle/input/world-population-data/world_population_data.csv')

# %% [markdown]
# <a id="2"></a>
#
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">2. Dataset Description</p>
#
# <div style = "color: Black; display: fill;
#               border-radius: 5px;
#               background-color: #F2E6CE;
#               font-size: 100%;
#               font-family: Verdana">
#     <p style = "padding: 7px; color: Black;">
#         <ul>
#     📌 <b>Rank</b> - Rank by Population<br>
#     📌 <b>CCA3</b> - 3 Digit Country/Territories Code<br>
#     📌 <b>Country</b> - Name of the Country<br>
#     📌 <b>Continent</b> - Name of the Continent<br>
#     📌 <b>2023 Population</b> - Population of the Country in the year 2023<br>
#     📌 <b>2022 Population</b> - Population of the Country in the year 2022<br>
#     📌 <b>2020 Population</b> - Population of the Country in the year 2020<br>
#     📌 <b>2015 Population</b> - Population of the Country in the year 2015<br>
#     📌 <b>2010 Population</b> - Population of the Country in the year 2010<br>
#     📌 <b>2000 Population</b> - Population of the Country in the year 2000<br>
#     📌 <b>1990 Population</b> - Population of the Country in the year 1990<br>
#     📌 <b>1980 Population</b> - Population of the Country in the year 1980<br>
#     📌 <b>1970 Population</b> - Population of the Country in the year 1970<br>
#     📌 <b>Area (km²)</b> - Area size of the Country/Territories in square kilometer<br>
#     📌 <b>Density (km²)</b> - Population Density per square kilometer<br>
#     📌 <b>Growth Rate</b> - Population Growth Rate by Country<br>
#     📌 <b>World Population Percentage</b> - The population percentage by each Country<br>
# </ul>

# %% [markdown]
# **Quick Glimpse of the Dataset**

# %%
# Taking a look at the first several winners
df.head(n=5).style.set_properties(**{"background-color": "#417894","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">3. Basic Exploration</p>

# %% [markdown]
# **Understanding the Dataset**

# %%
# Checking shape of the dataset
print(f"Shape Of The Dataset: {df.shape}")
# Out:
# Shape Of The Dataset: (234, 17)

# %% [markdown]
# **Summary of the Dataset**

# %%
# Checking the summary statistics
df.describe().style.set_properties(**{"background-color": "#417894", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# **Checking the Data Types**

# %%
# Gathering bsic information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rank              234 non-null    int64
#  1   cca3              234 non-null    object
#  2   country           234 non-null    object
#  3   continent         234 non-null    object
#  4   2023 population   234 non-null    int64
#  5   2022 population   234 non-null    int64
#  6   2020 population   234 non-null    int64
#  7   2015 population   234 non-null    int64
#  8   2010 population   234 non-null    int64
#  9   2000 population   234 non-null    int64
#  10  1990 population   234 non-null    int64
#  11  1980 population   234 non-null    int64
#  12  1970 population   234 non-null    int64
#  13  area (km²)        234 non-null    float64
#  14  density (km²)     234 non-null    int64
#  15  growth rate       234 non-null    object
# ...

# %% [markdown]
# **Checking the Missing Value**

# %%
# Checking if there any Null value present in the dataset
df.isnull().sum().to_frame().T.style.set_properties(**{"background-color": "#417894","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_3e5e8_row0_col0, #T_3e5e8_row0_col1, #T_3e5e8_row0_col2, #T_3e5e8_row0_col3, #T_3e5e8_row0_col4, #T_3e5e8_row0_col5, #T_3e5e8_row0_col6, #T_3e5e8_row0_col7, #T_3e5e8_row0_col8, #T_3e5e8_row0_col9, #T_3e5e8_row0_col10, #T_3e5e8_row0_col11, #T_3e5e8_row0_col12, #T_3e5e8_row0_col13, #T_3e5e8_row0_col14, #T_3e5e8_row0_col15, #T_3e5e8_row0_col16 {
#   background-color: #417894;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_3e5e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e5e8_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_3e5e8_level0_col1" class="col_heading level0 col1" >cca3</th>
#       <th id="T_3e5e8_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_3e5e8_level0_col3" class="col_heading level0 col3" >continent</th>
#       <th id="T_3e5e8_level0_col4" class="col_heading level0 col4" >2023 population</th>
# ...

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">4. Dataset Summary</p>

# %% [markdown]
# **Checking the Duplicate Value**

# %%
# Checking if there any duplicate value present in the dataset
print(f'There is {df.duplicated().sum()} duplicate value.')
# Out:
# There is 0 duplicate value.

# %% [markdown]
# **Checking the Unique Value**

# %%
# Checking the number of unique values
df.nunique().to_frame().T.style.set_properties(**{"background-color": "#417894", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_13e9d_row0_col0, #T_13e9d_row0_col1, #T_13e9d_row0_col2, #T_13e9d_row0_col3, #T_13e9d_row0_col4, #T_13e9d_row0_col5, #T_13e9d_row0_col6, #T_13e9d_row0_col7, #T_13e9d_row0_col8, #T_13e9d_row0_col9, #T_13e9d_row0_col10, #T_13e9d_row0_col11, #T_13e9d_row0_col12, #T_13e9d_row0_col13, #T_13e9d_row0_col14, #T_13e9d_row0_col15, #T_13e9d_row0_col16 {
#   background-color: #417894;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_13e9d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13e9d_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_13e9d_level0_col1" class="col_heading level0 col1" >cca3</th>
#       <th id="T_13e9d_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_13e9d_level0_col3" class="col_heading level0 col3" >continent</th>
#       <th id="T_13e9d_level0_col4" class="col_heading level0 col4" >2023 population</th>
# ...

# %% [markdown]
# **Data Types of the Features**

# %%
df.dtypes.to_frame().T.style.set_properties(**{"background-color": "#417894","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_7a5a6_row0_col0, #T_7a5a6_row0_col1, #T_7a5a6_row0_col2, #T_7a5a6_row0_col3, #T_7a5a6_row0_col4, #T_7a5a6_row0_col5, #T_7a5a6_row0_col6, #T_7a5a6_row0_col7, #T_7a5a6_row0_col8, #T_7a5a6_row0_col9, #T_7a5a6_row0_col10, #T_7a5a6_row0_col11, #T_7a5a6_row0_col12, #T_7a5a6_row0_col13, #T_7a5a6_row0_col14, #T_7a5a6_row0_col15, #T_7a5a6_row0_col16 {
#   background-color: #417894;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_7a5a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a5a6_level0_col0" class="col_heading level0 col0" >rank</th>
#       <th id="T_7a5a6_level0_col1" class="col_heading level0 col1" >cca3</th>
#       <th id="T_7a5a6_level0_col2" class="col_heading level0 col2" >country</th>
#       <th id="T_7a5a6_level0_col3" class="col_heading level0 col3" >continent</th>
#       <th id="T_7a5a6_level0_col4" class="col_heading level0 col4" >2023 population</th>
# ...

# %%
# Display summary statistics for categorical columns
df.describe(include="object").T.style.set_properties(**{"background-color": "#417894","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_6dd8d_row0_col0, #T_6dd8d_row0_col1, #T_6dd8d_row0_col2, #T_6dd8d_row0_col3, #T_6dd8d_row1_col0, #T_6dd8d_row1_col1, #T_6dd8d_row1_col2, #T_6dd8d_row1_col3, #T_6dd8d_row2_col0, #T_6dd8d_row2_col1, #T_6dd8d_row2_col2, #T_6dd8d_row2_col3, #T_6dd8d_row3_col0, #T_6dd8d_row3_col1, #T_6dd8d_row3_col2, #T_6dd8d_row3_col3, #T_6dd8d_row4_col0, #T_6dd8d_row4_col1, #T_6dd8d_row4_col2, #T_6dd8d_row4_col3 {
#   background-color: #417894;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_6dd8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dd8d_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6dd8d_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_6dd8d_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_6dd8d_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">5. Population Across Continent</p>

# %% [markdown]
# **Distribution of Countries by Continent**

# %%
# Set a color palette for the countplot
palette = "mako"

# Countplot of population distribution by continent
plt.figure(figsize=(12, 6))
ax = sns.countplot(x='continent', data=df, order=df['continent'].value_counts().index, palette=palette)

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Title and labels
plt.title('Distribution of Countries by Continent', fontsize=16)
plt.xlabel('Continent', fontsize=14)
plt.ylabel('Count', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Continent-wise Population**

# %%
# Calculate total population for each continent
continent_population = df.groupby('continent')['2023 population'].sum() / 1e6

# Sort the continents by population
sorted_continents = continent_population.sort_values(ascending=False).index

# Set color palette for the bar plot
palette = "viridis"

# Create a vertical bar plot using seaborn
plt.figure(figsize=(12, 8))
ax = sns.barplot(x=sorted_continents, y=continent_population[sorted_continents], palette=palette)

# Add values at the top of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}M', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Title and labels
plt.title('Continent-wise Population (in Millions)', fontsize=16)
plt.xlabel('Continent', fontsize=14)
plt.ylabel('Population (Millions)', fontsize=14)

# Show the plot
plt.show()

# %% [markdown]
# **Continent-wise Population Distribution**

# %%
# Set a color palette for the pie chart
colors = sns.color_palette('viridis')

# Calculate total population for each continent
continent_population = df.groupby('continent')['2023 population'].sum()

# Create a full pie chart with the custom palette
plt.figure(figsize=(10, 8))
plt.pie(continent_population, labels=continent_population.index, autopct='%1.1f%%', colors=colors, startangle=90)

# Title
plt.title('Continent-wise Population Distribution', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# **Continent-wise Population (Interactive)**

# %%
# Calculate total population for each continent
continent_population = df.groupby('continent')['2023 population'].sum() / 1e6
# Sort the continents by population in descending order
sorted_continents = continent_population.sort_values(ascending=False).index

# Create a custom color palette
custom_palette = ["#440154", "#482677", "#3E4989", "#31688E", "#26828E", "#1F9E89", "#35B779", "#6DCD59", "#B4DE2C", "#FDE725"]

# Create a bar plot for continent-wise population
fig = px.bar(df, 
             x='continent', 
             y='2023 population', 
             color='continent', 
             color_discrete_sequence=custom_palette,  # Set custom color palette
             category_orders={'continent': sorted_continents},  # Sort by population
             labels={'2023 population': 'Population (Millions)'},
             title='Continent-wise Population (2023)',
             hover_name='continent')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="34df7e54-0d9f-408f-ba83-957e8b38faeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("34df7e54-0d9f-408f-ba83-957e8b38faeb")) {                    Plotly.newPlot(                        "34df7e54-0d9f-408f-ba83-957e8b38faeb",                        [{"alignmentgroup":"True","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ePopulation (Millions)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia","Asia"
# ...

# %% [markdown]
# <a id="6"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">6. Population Facts</p>

# %% [markdown]
# **Top 10 Most Populated Countries**

# %%
# Convert population to millions
df['2023 population (millions)'] = df['2023 population'] / 1e6

# Sort the DataFrame by population in descending order
df_sorted = df.sort_values(by='2023 population (millions)', ascending=False)

# Take the top 10 populated countries
top_10_countries = df_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='country', y='2023 population (millions)', data=top_10_countries, palette='viridis')

# Display values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.1f}M', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Title and labels
plt.title('Top 10 Most Populated Countries (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population (Millions)', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Least Populated Countries**

# %%
# Sort the DataFrame by population in ascending order
df_sorted = df.sort_values(by='2023 population')

# Take the bottom 10 populated countries (least populated)
bottom_10_countries = df_sorted.head(10)

# Create a bar plot
plt.figure(figsize=(12, 6))
ax = sns.barplot(x='country', y='2023 population', data=bottom_10_countries, palette='mako')

# Display values at the top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height():,.0f}', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Title and labels
plt.title('Top 10 Least Populated Countries (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population', fontsize=14)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Remove grid lines
ax.yaxis.grid(False)

# Show the plot
plt.show()

# %% [markdown]
# **Top 10 Countries in Asia**

# %%
# Filter data for Asia and sort by population in 2023
asia_population_2023 = df[df['continent'] == 'Asia'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in Asia by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=asia_population_2023, palette='viridis')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in Asia by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Top 10 Countries in Africa**

# %%
# Filter data for Africa and sort by population in 2023
africa_population_2023 = df[df['continent'] == 'Africa'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in Africa by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=africa_population_2023, palette='mako')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in Africa by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Top 10 Countries in Europe**

# %%
# Filter data for Europe and sort by population in 2023
europe_population_2023 = df[df['continent'] == 'Europe'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in Europe by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=europe_population_2023, palette='viridis')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in Europe by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Top 10 Countries in North America**

# %%
# Filter data for North America and sort by population in 2023
namerica_population_2023 = df[df['continent'] == 'North America'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in North America by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=namerica_population_2023, palette='mako')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in North America by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Top 10 Countries in Souh America**

# %%
# Filter data for South America and sort by population in 2023
south_america_population_2023 = df[df['continent'] == 'South America'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in South America by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=south_america_population_2023, palette='viridis')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in South America by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Top 10 Countries in Ocenia**

# %%
# Filter data for Oceania and sort by population in 2023
oceania_population_2023 = df[df['continent'] == 'Oceania'].sort_values(by='2023 population', ascending=False).head(10)

# Vertical bar plot for top 10 countries in Oceania by population in 2023
plt.figure(figsize=(16, 6))
ax = sns.barplot(x='country', y='2023 population', data=oceania_population_2023, palette='mako')

# Add population values at the top of each bar in millions
for p in ax.patches:
    ax.annotate(f'{p.get_height() / 1e6:.2f}M', (p.get_x() + p.get_width() / 2, p.get_height()),
                ha='center', va='bottom', fontsize=12, color='black')

# Title and labels
plt.title('Top 10 Countries in Oceania by Population (2023)', fontsize=16)
plt.xlabel('Country', fontsize=14)
plt.ylabel('Population in 2023', fontsize=14)

# Remove grid lines
ax.yaxis.grid(False)

plt.show()

# %% [markdown]
# **Continent-wise Population Timeline**

# %%
# Select the continents of interest
continents_of_interest = ['Asia', 'Africa', 'Europe', 'North America', 'South America', 'Oceania']

# Filter the DataFrame to include only the specified continents
selected_continents_df = df[df['continent'].isin(continents_of_interest)]

# Melt the DataFrame to make it suitable for seaborn lineplot
melted_df_continents = selected_continents_df.melt(id_vars=['continent'], value_vars=['1970 population','1980 population','1990 population','2000 population', '2010 population', '2015 population', '2020 population', '2023 population'])

# Set color palette for the line plot
palette = "viridis"

# Create a line plot using seaborn
plt.figure(figsize=(20, 8))
ax = sns.lineplot(x='variable', y='value', hue='continent', data=melted_df_continents, palette=palette, marker='o')

# Title and labels
plt.title('Population Trends Over Time for Different Continents', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Population', fontsize=14)

# Add legend
plt.legend(title='Continent', loc='upper left', bbox_to_anchor=(1, 1))


# Add grid lines for better visibility
plt.grid(axis='both', linestyle='--', alpha=0.5, color='lightgray')

# Show the plot
plt.show()

# %% [markdown]
# <a id="7"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">7. World Population</p>

# %% [markdown]
# **Geographical Analysis of Population**

# %%
# Create a choropleth map for the world population 
fig = px.choropleth(df,
                    locations='cca3',
                    color='2023 population',
                    hover_name='country',
                    color_continuous_scale='YlGnBu',
                    title='World Population Distribution',
                    labels={'2023 population': 'Population'},
                    height=800,
                    width=1200)

# Show the interactive map
fig.show()
# Out:
# <div>                            <div id="3781627e-10f9-464b-8735-d6cdc657bc59" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3781627e-10f9-464b-8735-d6cdc657bc59")) {                    Plotly.newPlot(                        "3781627e-10f9-464b-8735-d6cdc657bc59",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecca3=%{location}\u003cbr\u003ePopulation=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico","Ethiopia","Japan","Philippines","Egypt","DR Congo","Vietnam","Iran","Turkey","Germany","Thailand","United Kingdom","Tanzania","France
# ...

# %%
# Set color palette for both plots
palette = "viridis"

# Extracting world population data
world_population = df[['2023 population', '2022 population', '2020 population', '2015 population', '2010 population', '2000 population', '1990 population', '1980 population', '1970 population']].sum() / 1e9
# Creating a line plot for world population trend
years = ['2023', '2022', '2020', '2015', '2010', '2000', '1990', '1980', '1970']

# Subplots
plt.figure(figsize=(18, 6))

# First subplot for the line plot
plt.subplot(1, 2, 1)
trend = df.iloc[:, 4:13].sum().sort_index()
sns.lineplot(x=trend.index, y=trend.values, marker="o", palette=palette, linewidth=2, markersize=8)
plt.axhline(0, color='black', linewidth=0.5, linestyle="--")
plt.title('World Population Trend (Line Plot)')
plt.xlabel('Year')
plt.ylabel('Population')

# Second subplot for the bar plot
plt.subplot(1, 2, 2)
bar_plot = sns.barplot(x=years, y=world_population, palette=palette)
plt.title('World Population Trend (Bar Plot)')
plt.xlabel('Year')
plt.ylabel('Population (Billions)')

# Annotate each bar with the population values in billions
for p in bar_plot.patches:
    bar_plot.annotate(f'{p.get_height():.2f}B', (p.get_x() + p.get_width() / 2., p.get_height()), ha='center', va='center', xytext=(0, 10), textcoords='offset points')

# Remove y-axis gridlines
bar_plot.yaxis.grid(False)    
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Growth Rate vs. Population Density (Interactive)**

# %%
# Create a custom color palette similar to viridis
custom_palette = ["#440154", "#482677", "#3E4989", "#31688E", "#26828E", "#1F9E89", "#35B779", "#6DCD59", "#B4DE2C", "#FDE725"]

# Scatter plot for growth rate and population density with Plotly
fig = px.scatter(df, x='density (km²)', y='growth rate', color='continent', size='2023 population',
                 hover_name='country', title='Growth Rate vs. Population Density',
                 labels={'density (km²)': 'Population Density (people/km²)', 'growth rate': 'Growth Rate'},
                 size_max=30,
                 color_discrete_sequence=custom_palette)  # Set custom color palette

# Update layout for better fitting
fig.update_layout(
    width=1200,
    height=800,
)

# Show the interactive plot
fig.show()
# Out:
# <div>                            <div id="7f30b46c-92e6-4c5b-9570-ff872423aa22" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f30b46c-92e6-4c5b-9570-ff872423aa22")) {                    Plotly.newPlot(                        "7f30b46c-92e6-4c5b-9570-ff872423aa22",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=Asia\u003cbr\u003ePopulation Density (people\u002fkm²)=%{x}\u003cbr\u003eGrowth Rate=%{y}\u003cbr\u003e2023 population=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["India","China","Indonesia","Pakistan","Bangladesh","Japan","Philippines","Vietnam","Iran","Turkey","Thailand","Myanmar","South Korea","Iraq","Afghanistan","Saudi Arabia","Uzbek
# ...

# %% [markdown]
# <a id="8"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">8. A Few More Facts</p>

# %% [markdown]
# **Population Trends of Top 3 Countries Over Time**

# %%
# Select the countries of interest
countries_of_interest = ['China', 'India', 'United States']

# Filter the DataFrame to include only the specified countries
selected_countries_df = df[df['country'].isin(countries_of_interest)]

# Melt the DataFrame to make it suitable for seaborn lineplot
melted_df = selected_countries_df.melt(id_vars=['country'], value_vars=['2000 population', '2010 population', '2015 population', '2020 population', '2023 population'])

# Set color palette for the line plot
palette = "mako"

# Create a line plot using seaborn
plt.figure(figsize=(12, 6))
ax = sns.lineplot(x='variable', y='value', hue='country', data=melted_df, palette=palette, marker='o')

# Title and labels
plt.title('Population Trends Over Time for India, China, USA', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Population', fontsize=14)

# Add legend
plt.legend(title='Country', loc='upper left', bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %%
# Scatter plot for population density and area
plt.figure(figsize=(10, 6))
sns.scatterplot(x='density (km²)', y='area (km²)', data=df, color='#6DCD59', alpha=0.7, edgecolor='black')

# Title and labels
plt.title('Population Density vs. Area', fontsize=16)
plt.xlabel('Population Density (people/km²)', fontsize=14)
plt.ylabel('Area (km²)', fontsize=14)

plt.show()

# %% [markdown]
# **Population vs Land Area**

# %%
# Define a style dictionary for the scatter plot
scatter_style = {
    'color': '#482677',
    'marker': 'o',
    'markersize': 50,
    'alpha': 0.7,
    'title': {'text': 'Population vs. Land Area', 'fontsize': 16, 'color': 'black'},
    'xlabel': {'text': 'Land Area (km²)', 'fontsize': 14, 'color': 'gray'},
    'ylabel': {'text': 'Population', 'fontsize': 14, 'color': 'gray'}
}

# Scatter plot for population vs. land area
plt.figure(figsize=(10, 6))
plt.scatter(df['area (km²)'], df['2023 population'], color=scatter_style['color'],
            marker=scatter_style['marker'], s=scatter_style['markersize'], alpha=scatter_style['alpha'])

# Title and labels
plt.title(scatter_style['title']['text'], fontsize=scatter_style['title']['fontsize'], color=scatter_style['title']['color'])
plt.xlabel(scatter_style['xlabel']['text'], fontsize=scatter_style['xlabel']['fontsize'], color=scatter_style['xlabel']['color'])
plt.ylabel(scatter_style['ylabel']['text'], fontsize=scatter_style['ylabel']['fontsize'], color=scatter_style['ylabel']['color'])

# Show the plot
plt.show()

# %% [markdown]
# <a id="9"></a>
# # <p style="padding:10px;background-color:#1EA8BD;margin:0;color:#FFF6F6;font-family:newtimeroman;font-size:150%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">Thank You!</p>
#
#
# <div style="text-align:center;">
#     <h3 style="color:#1EA8BD;">If you liked this notebook, upvote it. 🔼</h3>
# </div>
