# %% [markdown]
# <a href="https://www.kaggle.com/code/sazidthe1/eda-electricity-production?scriptVersionId=168534096" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:175%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">EDA | Electricity Production</p>
#
#
# <p style="text-align:center; ">
# <img src="https://img.freepik.com/free-photo/earth-bulb-dark-background_1379-506.jpg", style='width: 1000px; height: 600px;'>
# </p>
#
#
# The Global Electricity Production Dataset offers valuable insights into worldwide energy generation trends. With the world's increasing energy demands and the imperative shift towards sustainable energy sources, understanding electricity production dynamics becomes pivotal. This dataset encompasses diverse parameters, including country-wise production figures, variations in energy sources, and production methodologies. Through Exploratory Data Analysis (EDA), we aim to uncover patterns, trends, and relationships within the data.
#
# By leveraging visualization and statistical techniques, we can gain valuable insights into global energy production patterns and contribute to informed decision-making in energy policy and sustainability initiatives.

# %% [markdown]
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:100">Table of Contents</p>
#
#
# |No  | Contents |
# |:---| :---     |
# |1   | [<font color="#0f4c5c"> Importing Libraries</font>](#1)                   |
# |2   | [<font color="#0f4c5c"> Dataset Description</font>](#2)                   |
# |3   | [<font color="#0f4c5c"> Basic Exploration</font>](#3)                     |
# |4   | [<font color="#0f4c5c"> Dataset Summary</font>](#4)                       |
# |5   | [<font color="#0f4c5c"> Exploratory Data Analysis</font>](#5)           |

# %% [markdown]
# <a id="1"></a>
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Importing Libraries</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# **Reading the Dataset**

# %%
df = pd.read_csv('/kaggle/input/global-electricity-production/global_electricity_production_data.csv')

# %% [markdown]
# <a id="2"></a>
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Dataset Description</p>
#
# <div style = "color: Black; display: fill;
#               border-radius: 5px;
#               background-color: #c4d3b6;
#               font-size: 100%;
#               font-family: Verdana">
#     <p style = "padding: 7px; color: Black;">
#         <ul>
#     📌 <b>country_name</b> - Name of the Country<br>
#     📌 <b>date</b> - Date of the production<br>
#     📌 <b>parameter</b> - Parameter being measured in each row<br>
#     📌 <b>product</b> - Type of electricity product<br>
#     📌 <b>value</b> - Value of electricity production<br>
#     📌 <b>unit</b> - Unit of measurement for electricity production<br>
#        <br>
# </ul>

# %% [markdown]
# **Quick Glimpse of the Dataset**

# %%
df.head(n=5).style.set_properties(**{"background-color": "#43b4f7","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_ffa23_row0_col0, #T_ffa23_row0_col1, #T_ffa23_row0_col2, #T_ffa23_row0_col3, #T_ffa23_row0_col4, #T_ffa23_row0_col5, #T_ffa23_row1_col0, #T_ffa23_row1_col1, #T_ffa23_row1_col2, #T_ffa23_row1_col3, #T_ffa23_row1_col4, #T_ffa23_row1_col5, #T_ffa23_row2_col0, #T_ffa23_row2_col1, #T_ffa23_row2_col2, #T_ffa23_row2_col3, #T_ffa23_row2_col4, #T_ffa23_row2_col5, #T_ffa23_row3_col0, #T_ffa23_row3_col1, #T_ffa23_row3_col2, #T_ffa23_row3_col3, #T_ffa23_row3_col4, #T_ffa23_row3_col5, #T_ffa23_row4_col0, #T_ffa23_row4_col1, #T_ffa23_row4_col2, #T_ffa23_row4_col3, #T_ffa23_row4_col4, #T_ffa23_row4_col5 {
#   background-color: #43b4f7;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_ffa23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ffa23_level0_col0" class="col_heading level0 col0" >country_name</th>
#       <th id="T_ffa23_level0_col1" class="col_heading level0 col1" >date</th>
# ...

# %% [markdown]
# <a id="3"></a>
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Basic Exploration</p>

# %% [markdown]
# **Understanding the Dataset**

# %%
print(f"Shape Of The Dataset: {df.shape}")
# Out:
# Shape Of The Dataset: (121074, 6)

# %% [markdown]
# **Information about the Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121074 entries, 0 to 121073
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   country_name  121074 non-null  object
#  1   date          121074 non-null  object
#  2   parameter     121074 non-null  object
#  3   product       121074 non-null  object
#  4   value         121060 non-null  float64
#  5   unit          121074 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 5.5+ MB

# %% [markdown]
# **Checking the Missing Value**

# %%
df.isnull().sum().to_frame().style.set_properties(**{"background-color": "#43b4f7","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_396c5_row0_col0, #T_396c5_row1_col0, #T_396c5_row2_col0, #T_396c5_row3_col0, #T_396c5_row4_col0, #T_396c5_row5_col0 {
#   background-color: #43b4f7;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_396c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_396c5_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_396c5_level0_row0" class="row_heading level0 row0" >country_name</th>
#       <td id="T_396c5_row0_col0" class="data row0 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_396c5_level0_row1" class="row_heading level0 row1" >date</th>
#       <td id="T_396c5_row1_col0" class="data row1 col0" >0</td>
#     </tr>
#     <tr>
#       <th id="T_396c5_level0_row2" class="row_heading level0 row2" >parameter</th>
#       <td id="T_396c5_row2_col0" class="data row2 col0" >0</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# **Checking the Duplicate Value**

# %%
print(f'There is {df.duplicated().sum()} duplicate value.')
# Out:
# There is 0 duplicate value.

# %% [markdown]
# <a id="4"></a>
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Dataset Summary</p>

# %% [markdown]
# **Checking Summary Statistics - Numerical Columns**

# %%
df.describe().style.set_properties(**{"background-color": "#43b4f7","color":"white","border": "1.5px  solid black"})
# Out:
# <style type="text/css">
# #T_5412c_row0_col0, #T_5412c_row1_col0, #T_5412c_row2_col0, #T_5412c_row3_col0, #T_5412c_row4_col0, #T_5412c_row5_col0, #T_5412c_row6_col0, #T_5412c_row7_col0 {
#   background-color: #43b4f7;
#   color: white;
#   border: 1.5px  solid black;
# }
# </style>
# <table id="T_5412c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5412c_level0_col0" class="col_heading level0 col0" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5412c_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_5412c_row0_col0" class="data row0 col0" >121060.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5412c_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_5412c_row1_col0" class="data row1 col0" >6925.081490</td>
#     </tr>
#     <tr>
#       <th id="T_5412c_level0_row2" class="row_heading level0 row2" >std</th>
# ...

# %% [markdown]
# **Summary Statistics - Categorical Values**

# %%
df.describe(include=['object']).T.style.set_properties(**{"background-color": "#43b4f7", "color": "white", "border": "1.5px solid black"})
# Out:
# <style type="text/css">
# #T_a543b_row0_col0, #T_a543b_row0_col1, #T_a543b_row0_col2, #T_a543b_row0_col3, #T_a543b_row1_col0, #T_a543b_row1_col1, #T_a543b_row1_col2, #T_a543b_row1_col3, #T_a543b_row2_col0, #T_a543b_row2_col1, #T_a543b_row2_col2, #T_a543b_row2_col3, #T_a543b_row3_col0, #T_a543b_row3_col1, #T_a543b_row3_col2, #T_a543b_row3_col3, #T_a543b_row4_col0, #T_a543b_row4_col1, #T_a543b_row4_col2, #T_a543b_row4_col3 {
#   background-color: #43b4f7;
#   color: white;
#   border: 1.5px solid black;
# }
# </style>
# <table id="T_a543b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a543b_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a543b_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_a543b_level0_col2" class="col_heading level0 col2" >top</th>
#       <th id="T_a543b_level0_col3" class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# **Plotting Heatmap for Null Values**

# %%
sns.heatmap(df.isnull(), cmap="Blues")
# Out:
# <Axes: >

# %% [markdown]
# <a id="5"></a>
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Exploratory Data Analysis</p>

# %% [markdown]
# ### Univariate Analysis

# %%
# Set the style to white background
sns.set_style("white")

# Example of univariate analysis for numerical variable 'value'
plt.figure(figsize=(12, 6))
sns.histplot(df['value'].dropna(), bins=30, kde=True, color='blue')
plt.title('Distribution of Value')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Univariate Analysis - Categorical Variable

# %%
# Set the style to white background
sns.set_style("white")

# Example of univariate analysis for categorical variable 'country_name'
plt.figure(figsize=(12, 6))
sns.countplot(x='country_name', data=df, color='blue')
plt.title('Count of Data by Country')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# Set the style to white background
sns.set_style("white")

# Example of bivariate analysis between 'value' and 'country_name'
plt.figure(figsize=(12, 8))
sns.violinplot(x='country_name', y='value', data=df, color='blue')
plt.title('Value Distribution by Country')
plt.xticks(rotation=90)
plt.show()

# %%
# Set the style to white background
sns.set_style("white")

# Example of bivariate analysis between 'value' and 'parameter'
plt.figure(figsize=(12, 6))
sns.boxplot(x='parameter', y='value', data=df, color='blue')
plt.title('Value by Parameter')
plt.xticks(rotation=45)
plt.show()

# %%
# Set the style to white background
sns.set_style("white")

# Example of bivariate analysis between 'value' and 'parameter'
plt.figure(figsize=(10, 6))
sns.boxplot(x='product', y='value', data=df, color='blue')
plt.title('Value by Product')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # <p style="padding:20px;background-color:#43b4f7;margin:0;color:white;font-family:newtimeroman;font-size:150%;text-align:center;border-radius:10px 10px;overflow:hidden;font-weight:500">Thank You!</p>
# # <p style="padding:10px;background-color:sky;margin:0;color:#336699;font-family:newtimeroman;font-size:105%;text-align:center;border-radius: 10px 10px;overflow:hidden;font-weight:500">If you liked this notebook, please upvote 🔼</p>
